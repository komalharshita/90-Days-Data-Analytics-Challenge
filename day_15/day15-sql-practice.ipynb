# %%
import pandas as pd
import sqlite3

customers = pd.read_csv('/kaggle/input/day-15-datasets/day_15_customers.csv')
orders = pd.read_csv('/kaggle/input/day-15-datasets/day_15_orders.csv')

conn = sqlite3.connect(':memory:')
customers.to_sql('customers', conn, index=False, if_exists='replace')
orders.to_sql('orders', conn, index=False, if_exists='replace')
# Out:
# 18

# %%
pd.read_sql("SELECT * FROM orders LIMIT 5;", conn)
# Out:
#    order_id  customer_id  product     category  amount month
# 0       101            1   Laptop  Electronics   55000   Jan
# 1       102            1    Mouse  Electronics     700   Feb
# 2       103            2    Shoes      Fashion    2500   Jan
# 3       104            2  T-Shirt      Fashion    1200   Feb
# 4       105            2    Jeans      Fashion    3000   Mar

# %%
pd.read_sql("SELECT * FROM customers LIMIT 5;", conn)
# Out:
#    customer_id   name       city
# 0            1  Aanya      Delhi
# 1            2  Rohan     Mumbai
# 2            3  Mehul       Pune
# 3            4   Riya      Delhi
# 4            5  Kabir  Bangalore

# %% [markdown]
# # PART 1 — JOINS

# %% [markdown]
# **Show order_id, customer name, city, product, amount for all orders.**

# %%
query = """
SELECT o.order_id, c.name, c.city, o.product, o.amount
FROM orders o
JOIN customers c
ON o.customer_id = c.customer_id

"""

pd.read_sql(query, conn)
# Out:
#     order_id    name       city     product  amount
# 0        101   Aanya      Delhi      Laptop   55000
# 1        102   Aanya      Delhi       Mouse     700
# 2        103   Rohan     Mumbai       Shoes    2500
# 3        104   Rohan     Mumbai     T-Shirt    1200
# 4        105   Rohan     Mumbai       Jeans    3000
# 5        106   Mehul       Pune        Book     500
# 6        107    Riya      Delhi       Phone   20000
# 7        108    Riya      Delhi   Earphones    1500
# 8        109   Kabir  Bangalore      Tablet   28000
# 9        110   Kabir  Bangalore       Cover     800
# 10       111   Sneha     Mumbai  Makeup Kit    2200
# 11       112   Arjun    Chennai    Keyboard    1800
# 12       113   Pooja      Delhi       Shoes    2600
# 13       114   Pooja      Delhi      Jacket    4200
# 14       115   Tanvi       Pune    Notebook     300
# 15       116  Aditya  Bangalore  Headphones    3200
# 16       117  Aditya  Bangalore     Speaker    4500
# 17       118  Aditya  Bangalore     Charger     900

# %% [markdown]
# **Show all customers and their orders (even customers with no orders).**

# %%
query = """
SELECT c.customer_id, c.name, c.city, o.order_id, o.product, o.amount
FROM customers c
LEFT JOIN orders o
ON c.customer_id = o.customer_id

"""

pd.read_sql(query, conn)
# Out:
#     customer_id    name       city  order_id     product  amount
# 0             1   Aanya      Delhi       101      Laptop   55000
# 1             1   Aanya      Delhi       102       Mouse     700
# 2             2   Rohan     Mumbai       103       Shoes    2500
# 3             2   Rohan     Mumbai       104     T-Shirt    1200
# 4             2   Rohan     Mumbai       105       Jeans    3000
# 5             3   Mehul       Pune       106        Book     500
# 6             4    Riya      Delhi       107       Phone   20000
# 7             4    Riya      Delhi       108   Earphones    1500
# 8             5   Kabir  Bangalore       109      Tablet   28000
# 9             5   Kabir  Bangalore       110       Cover     800
# 10            6   Sneha     Mumbai       111  Makeup Kit    2200
# 11            7   Arjun    Chennai       112    Keyboard    1800
# 12            8   Pooja      Delhi       113       Shoes    2600
# 13            8   Pooja      Delhi       114      Jacket    4200
# 14            9   Tanvi       Pune       115    Notebook     300
# 15           10  Aditya  Bangalore       116  Headphones    3200
# 16           10  Aditya  Bangalore       117     Speaker    4500
# 17           10  Aditya  Bangalore       118     Charger     900

# %% [markdown]
# **Show customers who have never placed an order.**

# %%
query = """
SELECT 
    c.customer_id,
    c.name,
    c.city
FROM customers c
LEFT JOIN orders o
ON c.customer_id = o.customer_id
WHERE o.order_id IS NULL ;

"""

pd.read_sql(query, conn)
# Out:
# Empty DataFrame
# Columns: [customer_id, name, city]
# Index: []

# %% [markdown]
# # PART 2 — JOIN + GROUP BY

# %% [markdown]
# **Total spending per customer.**

# %%
query = """
SELECT c.name, SUM(o.amount) AS total_spent
FROM customers c
JOIN orders o
ON c.customer_id = o.customer_id
GROUP BY c.name ;

"""

pd.read_sql(query, conn)
# Out:
#      name  total_spent
# 0   Aanya        55700
# 1  Aditya         8600
# 2   Arjun         1800
# 3   Kabir        28800
# 4   Mehul          500
# 5   Pooja         6800
# 6    Riya        21500
# 7   Rohan         6700
# 8   Sneha         2200
# 9   Tanvi          300

# %% [markdown]
# **Total revenue per city.**

# %%
query = """
SELECT c.city, SUM(o.amount) AS total_revenue
FROM customers c
JOIN orders o
ON c.customer_id = o.customer_id
GROUP BY c.city ;

"""

pd.read_sql(query, conn)
# Out:
#         city  total_revenue
# 0  Bangalore          37400
# 1    Chennai           1800
# 2      Delhi          84000
# 3     Mumbai           8900
# 4       Pune            800

# %% [markdown]
# **Number of orders per category.**

# %%
query = """
SELECT o.category, COUNT(o.order_id) AS total_orders
FROM orders o
GROUP BY o.category;

"""

pd.read_sql(query, conn)
# Out:
#       category  total_orders
# 0  Accessories             1
# 1       Beauty             1
# 2    Education             2
# 3  Electronics             9
# 4      Fashion             5

# %% [markdown]
# # PART 3 — SIMPLE WINDOW FUNCTIONS

# %% [markdown]
# **Rank orders by amount within each customer (use ROW_NUMBER)**

# %%
query = """
SELECT customer_id, order_id, amount,
    ROW_NUMBER() OVER (
        PARTITION BY customer_id
        ORDER BY amount DESC
    ) AS rank_per_customer
FROM orders ;

"""

pd.read_sql(query, conn)
# Out:
#     customer_id  order_id  amount  rank_per_customer
# 0             1       101   55000                  1
# 1             1       102     700                  2
# 2             2       105    3000                  1
# 3             2       103    2500                  2
# 4             2       104    1200                  3
# 5             3       106     500                  1
# 6             4       107   20000                  1
# 7             4       108    1500                  2
# 8             5       109   28000                  1
# 9             5       110     800                  2
# 10            6       111    2200                  1
# 11            7       112    1800                  1
# 12            8       114    4200                  1
# 13            8       113    2600                  2
# 14            9       115     300                  1
# 15           10       117    4500                  1
# 16           10       116    3200                  2
# 17           10       118     900                  3

# %% [markdown]
# **Find the most expensive order per customer using ranking.**

# %%
query = """
SELECT *
FROM (
    SELECT customer_id, order_id, amount, 
        ROW_NUMBER() OVER (
            PARTITION BY customer_id
            ORDER BY amount desc
        ) AS rn
    FROM orders
) t
WHERE rn = 1 ;

"""

pd.read_sql(query, conn)
# Out:
#    customer_id  order_id  amount  rn
# 0            1       101   55000   1
# 1            2       105    3000   1
# 2            3       106     500   1
# 3            4       107   20000   1
# 4            5       109   28000   1
# 5            6       111    2200   1
# 6            7       112    1800   1
# 7            8       114    4200   1
# 8            9       115     300   1
# 9           10       117    4500   1

# %% [markdown]
# # PART 4 — LEAD / LAG (Intro level)

# %% [markdown]
# **For each customer, show their current order amount and previous order amount.**

# %%
query = """
SELECT customer_id, order_id, month, amount AS current_amount,
    LAG(amount) OVER(
        PARTITION BY customer_id
        ORDER BY month
    ) AS previous_amount
FROM orders ;

"""

pd.read_sql(query, conn)
# Out:
#     customer_id  order_id month  current_amount  previous_amount
# 0             1       102   Feb             700              NaN
# 1             1       101   Jan           55000            700.0
# 2             2       104   Feb            1200              NaN
# 3             2       103   Jan            2500           1200.0
# 4             2       105   Mar            3000           2500.0
# 5             3       106   Jan             500              NaN
# 6             4       107   Feb           20000              NaN
# 7             4       108   Mar            1500          20000.0
# 8             5       110   Feb             800              NaN
# 9             5       109   Jan           28000            800.0
# 10            6       111   Mar            2200              NaN
# 11            7       112   Jan            1800              NaN
# 12            8       113   Mar            2600              NaN
# 13            8       114   Mar            4200           2600.0
# 14            9       115   Feb             300              NaN
# 15           10       117   Feb            4500              NaN
# 16           10       116   Jan            3200           4500.0
# 17           10       118   Mar             900           3200.0

# %% [markdown]
# # PART 5 — CTE (Clean structuring)

# %% [markdown]
# **10. Use a CTE to calculate total spending per customer, then show only customers who spent more than 5000.**

# %%
query = """

WITH spending AS (
    SELECT c.name, SUM(o.amount) AS total_spent
    FROM customers c
    JOIN orders o
    ON c.customer_id = o.customer_id
    GROUP BY c.name
) 
SELECT *
FROM spending
WHERE total_spent > 5000
;

"""

pd.read_sql(query, conn)
# Out:
#      name  total_spent
# 0   Aanya        55700
# 1  Aditya         8600
# 2   Kabir        28800
# 3   Pooja         6800
# 4    Riya        21500
# 5   Rohan         6700
