# %% [markdown]
# # Day 24 — Pandas Foundations Practice

# %%
import pandas as pd
df = pd.read_csv("day_24_data.csv")
df.head()

# %% [markdown]
# ## Inspect Data

# %%
df.tail()
df.info()
df.describe()

# %% [markdown]
# ## Selecting Columns

# %%
df["name"]
df[["name","city"]]

# %% [markdown]
# ## Filtering Rows

# %%
df[df["math_score"] > 85]
df[df["city"] == "Delhi"]

# %% [markdown]
# ## Practice Exercises

# %%
# EXERCISE 1: Show students with attendance > 90

# EXERCISE 2: Show names and science_score of Pune students

# EXERCISE 3: Find average math_score
